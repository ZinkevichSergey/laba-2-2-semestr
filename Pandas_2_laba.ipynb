# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates
import datetime as dt
import matplotlib as mpl
import matplotlib.cbook as cbook
from matplotlib import pyplot as plt

# %%
city = pd.read_csv('city.csv')

# %% [markdown]
# Столбцы и количество строк в таблице city

# %%
city.columns
# Out:
# Index(['address', 'postal_code', 'country', 'federal_district', 'region_type',
#        'region', 'area_type', 'area', 'city_type', 'city', 'settlement_type',
#        'settlement', 'kladr_id', 'fias_id', 'fias_level', 'capital_marker',
#        'okato', 'oktmo', 'tax_office', 'timezone', 'geo_lat', 'geo_lon',
#        'population', 'foundation_year'],
#       dtype='object')

# %%
len(city)
# Out:
# 1117

# %% [markdown]
# Узнали самое длинное название города в таблице

# %%
q=[]
for i in city["city"]:
    i = str(i)
    q.append(i)
print(f'Самое длинное название города в таблице имеет {len(max(list, key=len))} символов')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3975d234bc7a> in <module>
#       3     i = str(i)
#       4     q.append(i)
# ----> 5 print(f'Самое длинное название города в таблице имеет {len(max(list, key=len))} символов')
#
# TypeError: 'type' object is not iterable

# %% [markdown]
# Количество городов для каждого часового пояса в Сибирском и Приволжском федеральных округах
# Ответ: 58

# %%
time = city[city['federal_district'].isin(['Приволжский', 'Сибирский'])]
time[['timezone','address']].groupby('timezone').count().rename({'address': 'Количество городов'}, axis=1)

# %% [markdown]
# Количество городов в каждом часовом поясе, отсортированное по убыванию.

# %%
q = city[['timezone','address']].groupby('timezone').count().sort_values('address', ascending=False)
q.rename({'address': 'Количество городов'}, axis=1)

# %% [markdown]
# Индивидуальное задание

# %%
airports = pd.read_csv('airports.csv')
airports
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 68328   46378  ZZ-0001       heliport                     Sealand Helipad
# 68329  307326  ZZ-0002  small_airport           Glorioso Islands Airstrip
# 68330  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 68331  342102     ZZZW         closed              Scandium City Heliport
# 68332  313629     ZZZZ  small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 1         38.704022    -101.473911        3435.0       NaN          US
# 2         59.947733    -151.692524         450.0       NaN          US
# 3         34.864799     -86.770302         820.0       NaN          US
# 4         35.608700     -91.254898         237.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 68328     51.894444       1.482500          40.0        EU          GB
# 68329    -11.584278      47.296389          11.0        AF          TF
# 68330     32.110587     -97.356312         690.0       NaN          US
# 68331     69.355287    -138.939310           4.0       NaN          CA
# 68332     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# 0          US-PA             Bensalem                no      00A       NaN
# 1          US-KS                Leoti                no     00AA       NaN
# 2          US-AK         Anchor Point                no     00AK       NaN
# 3          US-AL              Harvest                no     00AL       NaN
# 4          US-AR              Newport                no      NaN       NaN
# ...          ...                  ...               ...      ...       ...
# 68328     GB-ENG              Sealand                no      NaN       NaN
# 68329     TF-U-A     Grande Glorieuse                no      NaN       NaN
# 68330      US-TX                 Blum                no     87TX       NaN
# 68331      CA-YT  (Old) Scandium City                no     ZZZW       ZYW
# 68332      JP-46              Mishima                no     RJX7       NaN
#
#       local_code                   home_link  \
# 0            00A                         NaN
# 1           00AA                         NaN
# 2           00AK                         NaN
# 3           00AL                         NaN
# 4            NaN                         NaN
# ...          ...                         ...
# 68328        NaN  http://www.sealandgov.org/
# 68329        NaN                         NaN
# 68330       87TX                         NaN
# 68331       YK96                         NaN
# 68332       RJX7                         NaN
#
#                                           wikipedia_link              keywords
# 0                                                    NaN                   NaN
# 1                                                    NaN                   NaN
# 2                                                    NaN                   NaN
# 3                                                    NaN                   NaN
# 4                                                    NaN                  00AR
# ...                                                  ...                   ...
# 68328  https://en.wikipedia.org/wiki/Principality_of_...  Roughs Tower Helipad
# 68329                                                NaN                   NaN
# 68330                                                NaN                   NaN
# 68331                                                NaN                   NaN
# 68332  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...  SATSUMA,IWOJIMA,RJX7
#
# [68333 rows x 18 columns]

# %% [markdown]
# Cделал поиск по некоторым из имён имеющимся в таблице

# %%
df1 = pd.DataFrame({'id' : [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})
df2 = pd.DataFrame({'id' : [3], 'name': ['Hermione Granger']})
pd.concat([df1, df2]) .reset_index (drop=True)
# Out:
#    id              name
# 0   1      Harry Potter
# 1   2       Ron Weasley
# 2   3  Hermione Granger

# %%
airports.groupby(['iso_country', 'type']).size
# Out:
# <bound method GroupBy.size of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000266419B7E50>>

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type                             name  \
# 0        6523      00A  heliport                Total Rf Heliport
# 9      322658     00CN  heliport  Kitchen Creek Helibase Heliport
# 12       6532     00FD  heliport               Ringhaver Heliport
# 15       6535     00GE  heliport                 Caffrey Heliport
# 16       6536     00HI  heliport               Kaupulehu Heliport
# ...       ...      ...       ...                              ...
# 67976  347768  ZA-0251  heliport               Eagle View Helipad
# 68029  339169     ZGNT  heliport         Shenzhen Nantou Heliport
# 68054  301278      ZIZ  heliport                 Zamzama Heliport
# 68277  345912  ZW-0048  heliport           Chinyike Mine Heliport
# 68328   46378  ZZ-0001  heliport                  Sealand Helipad
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 9         32.727374    -116.459742        3350.0       NaN          US
# 12        28.846600     -82.345398          25.0       NaN          US
# 15        33.889245     -84.737930         957.0       NaN          US
# 16        19.832715    -155.980233          43.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 67976    -25.390456      30.172134           NaN        AF          ZA
# 68029     22.558736     113.925612           NaN        AS          CN
# 68054     26.710944      67.667250         128.0        AS          PK
# 68277    -18.925900      30.274200           NaN        AF          ZW
# 68328     51.894444       1.482500          40.0        EU          GB
#
#       iso_region        municipality scheduled_service gps_code iata_code  \
# 0          US-PA            Bensalem                no      00A       NaN
# 9          US-CA         Pine Valley                no     00CN       NaN
# 12         US-FL           Riverview                no     00FD       NaN
# 15         US-GA               Hiram                no     00GE       NaN
# 16         US-HI         Kailua-Kona                no     00HI       NaN
# ...          ...                 ...               ...      ...       ...
# 67976      ZA-MP          Walkersons                no      NaN       NaN
# 68029      CN-44  Shenzhen (Nanshan)                no     ZGNT       NaN
# 68054      PK-SD   Zamzama Gas Field                no      NaN       ZIZ
# 68277     ZW-U-A                 NaN                no      NaN       NaN
# 68328     GB-ENG             Sealand                no      NaN       NaN
#
#       local_code                   home_link  \
# 0            00A                         NaN
# 9           00CN                         NaN
# 12          00FD                         NaN
# 15          00GE                         NaN
# 16          00HI                         NaN
# ...          ...                         ...
# 67976       FAEV                         NaN
# 68029        NaN                         NaN
# 68054        NaN                         NaN
# 68277        NaN                         NaN
# 68328        NaN  http://www.sealandgov.org/
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 9                                                    NaN
# 12                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# ...                                                  ...
# 67976                                                NaN
# 68029                                                NaN
# 68054                                                NaN
# 68277                                                NaN
# 68328  https://en.wikipedia.org/wiki/Principality_of_...
#
#                           keywords
# 0                              NaN
# 9                              NaN
# 12                             NaN
# 15                             NaN
# 16                             NaN
# ...                            ...
# 67976  Eagle, view, Cabin, helipad
# 68029                          NaN
# 68054                          NaN
# 68277                          NaN
# 68328         Roughs Tower Helipad
#
# [16598 rows x 18 columns]

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')][['ident','name', 'municipality']]
# Out:
#       ident                                               name   municipality
# 32088  KACV  California Redwood Coast-Humboldt County Inter...  Arcata/Eureka
# 32238  KBAB                               Beale Air Force Base     Marysville
# 32491  KCMA                    Camarillo International Airport      Camarillo
# 33084  KEDW                             Edwards Air Force Base        Edwards
# 33859  KL45                  Bakersfield International Airport    Bakersfield
# 33883  KLAX                  Los Angeles International Airport    Los Angeles
# 34412  KOAK         Metropolitan Oakland International Airport        Oakland
# 34468  KONT                      Ontario International Airport        Ontario
# 35998  KSAN                    San Diego International Airport      San Diego
# 36038  KSFO                San Francisco International Airport  San Francisco
# 36059  KSJC    Norman Y. Mineta San Jose International Airport       San Jose
# 36081  KSMF                   Sacramento International Airport     Sacramento
# 36387  KVIS                      Visalia International Airport        Visalia

# %%
q_1 = airports[airports['elevation_ft'] == 3200.0]
q_2 = q_1[q_1['elevation_ft'] == 3200.0]
x = q_2['ident']
y = q_2['id']
plt.figure(figsize=(15, 9))
plt.bar(x, y,)
plt.setp(plt.xticks()[1], rotation=45, ha='right')
plt.xlabel("Наименование аэропортов, из которых были совершены вылеты", fontsize=21)
plt.ylabel("Высота, выраженная в футах", fontsize=17)
plt.title("Из каких аэропортов и на какой высоте летали самолёты,высота отображена в футах", fontsize=23)
plt.grid(which="major", linewidth=1, color="black")
plt.grid(which="minor", linestyle="--", color="grey", linewidth=0.6)

# %% [markdown]
# <img src="files/123.jpg">
